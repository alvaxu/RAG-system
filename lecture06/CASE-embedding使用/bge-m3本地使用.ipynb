# %%
#模型下载
from modelscope import snapshot_download
model_dir = snapshot_download('BAAI/bge-m3', cache_dir='C:\\Users\\Administrator\\AInewModels')
# Out:
# Downloading Model from https://www.modelscope.cn to directory: C:\Users\Administrator\AInewModels\BAAI\bge-m3
# 2025-04-18 14:51:28,191 - modelscope - INFO - Got 29 files, start to download ...
# Processing 29 items:   0%|                                                                 | 0.00/29.0 [00:00<?, ?it/s]
#
# Downloading [colbert_linear.pt]:   0%|                                                     | 0.00/2.00M [00:00<?, ?B/s]
# Downloading [imgs/bm25.jpg]:   0%|                                                          | 0.00/129k [00:00<?, ?B/s]
#
#
# Downloading [1_Pooling/config.json]:   0%|                                                   | 0.00/191 [00:00<?, ?B/s]
#
#
#
# Downloading [config.json]:   0%|                                                             | 0.00/687 [00:00<?, ?B/s]
#
#
#
#
# Downloading [onnx/config.json]:   0%|                                                        | 0.00/698 [00:00<?, ?B/s]
#
#
#
#
#
# Downloading [config_sentence_transformers.json]:   0%|                                       | 0.00/123 [00:00<?, ?B/s]
#
#
#
#
#
#
#
# Downloading [configuration.json]:   0%|                                                     | 0.00/77.0 [00:00<?, ?B/s]
#
#
#
#
#
#
# Downloading [onnx/Constant_7_attr__value]:   0%|                                           | 0.00/64.0k [00:00<?, ?B/s]
#
#
# Downloading [1_Pooling/config.json]: 100%|██████████████████████████████████████████████| 191/191 [00:00<00:00, 710B/s]
# Processing 29 items:   3%|██                                                        | 1.00/29.0 [00:00<00:09, 3.00it/s]
#
#
# Downloading [imgs/long.jpg]:   0%|                                                          | 0.00/474k [00:00<?, ?B/s]
#
#
#
# Downloading [config.json]: 100%|██████████████████████████████████████████████████████| 687/687 [00:00<00:00, 2.14kB/s]
#
#
#
#
#
# Downloading [config_sentence_transformers.json]: 100%|██████████████████████████████████| 123/123 [00:00<00:00, 418B/s]
#
#
#
#
# Downloading [onnx/config.json]: 100%|█████████████████████████████████████████████████| 698/698 [00:00<00:00, 2.32kB/s]
# Downloading [config_sentence_transformers.json]: 100%|██████████████████████████████████| 123/123 [00:00<00:00, 398B/s]
# Downloading [config.json]: 100%|██████████████████████████████████████████████████████| 687/687 [00:00<00:00, 2.01kB/s]
# Downloading [onnx/config.json]: 100%|█████████████████████████████████████████████████| 698/698 [00:00<00:00, 2.19kB/s]
# Downloading [imgs/bm25.jpg]: 100%|███████████████████████████████████████████████████| 129k/129k [00:00<00:00, 369kB/s]
#
#
#
#
#
#
#
# Downloading [onnx/Constant_7_attr__value]: 100%|███████████████████████████████████| 64.0k/64.0k [00:00<00:00, 212kB/s]
#
#
#
#
#
#
#
# Downloading [configuration.json]: 100%|███████████████████████████████████████████████| 77.0/77.0 [00:00<00:00, 242B/s]
#
# Downloading [configuration.json]: 100%|███████████████████████████████████████████████| 77.0/77.0 [00:00<00:00, 228B/s]
# Downloading [onnx/Constant_7_attr__value]: 100%|███████████████████████████████████| 64.0k/64.0k [00:00<00:00, 197kB/s]
#
# Downloading [long.jpg]:   0%|                                                               | 0.00/124k [00:00<?, ?B/s]
#
#
#
# Downloading [imgs/miracl.jpg]:   0%|                                                        | 0.00/563k [00:00<?, ?B/s]
#
#
#
#
#
# Downloading [onnx/model.onnx]:   0%|                                                        | 0.00/708k [00:00<?, ?B/s]
#
#
#
#
# Downloading [colbert_linear.pt]: 100%|████████████████████████████████████████████| 2.00M/2.00M [00:00<00:00, 4.99MB/s]
#
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   0%|                                                  | 0.00/2.11G [00:00<?, ?B/s]
#
# Processing 29 items:  28%|████████████████                                          | 8.00/29.0 [00:00<00:00, 21.7it/s]
#
#
#
#
#
#
#
# Downloading [imgs/nqa.jpg]:   0%|                                                           | 0.00/155k [00:00<?, ?B/s]
#
#
# Downloading [imgs/long.jpg]: 100%|██████████████████████████████████████████████████| 474k/474k [00:00<00:00, 1.54MB/s]
#
#
#
# Downloading [imgs/others.webp]:   0%|                                                      | 0.00/20.5k [00:00<?, ?B/s]
#
# Downloading [modules.json]: 100%|█████████████████████████████████████████████████████| 349/349 [00:00<00:00, 1.31kB/s]
#
# Downloading [long.jpg]: 100%|████████████████████████████████████████████████████████| 124k/124k [00:00<00:00, 407kB/s]
#
# Downloading [pytorch_model.bin]:   0%|                                                     | 0.00/2.12G [00:00<?, ?B/s]
#
#
#
# Downloading [imgs/miracl.jpg]: 100%|████████████████████████████████████████████████| 563k/563k [00:00<00:00, 1.84MB/s]
#
# Downloading [imgs/miracl.jpg]: 100%|████████████████████████████████████████████████| 563k/563k [00:00<00:00, 1.77MB/s]
# Processing 29 items:  41%|████████████████████████                                  | 12.0/29.0 [00:00<00:00, 17.0it/s]
#
#
#
# Downloading [sentence_bert_config.json]:   0%|                                              | 0.00/54.0 [00:00<?, ?B/s]
#
#
#
#
#
#
#
# Downloading [imgs/nqa.jpg]: 100%|████████████████████████████████████████████████████| 155k/155k [00:00<00:00, 494kB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx]: 100%|████████████████████████████████████████████████| 708k/708k [00:00<00:00, 2.02MB/s]
#
#
#
#
#
#
#
# Downloading [onnx/model.onnx]: 100%|████████████████████████████████████████████████| 708k/708k [00:00<00:00, 1.95MB/s]
#
#
#
#
#
#
# Downloading [sentencepiece.bpe.model]:   0%|                                               | 0.00/4.83M [00:00<?, ?B/s]
#
#
#
#
# Downloading [imgs/mkqa.jpg]: 100%|██████████████████████████████████████████████████| 594k/594k [00:00<00:00, 1.44MB/s]
# Processing 29 items:  52%|██████████████████████████████                            | 15.0/29.0 [00:00<00:00, 19.4it/s]
#
#
#
#
# Downloading [sparse_linear.pt]:   0%|                                                      | 0.00/3.43k [00:00<?, ?B/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   0%|                                         | 1.00M/2.11G [00:00<18:28, 2.04MB/s]
#
#
# Downloading [imgs/others.webp]: 100%|█████████████████████████████████████████████| 20.5k/20.5k [00:00<00:00, 55.5kB/s]
#
#
#
#
# Downloading [sentence_bert_config.json]: 100%|████████████████████████████████████████| 54.0/54.0 [00:00<00:00, 179B/s]
#
#
#
# Downloading [special_tokens_map.json]:   0%|                                                 | 0.00/964 [00:00<?, ?B/s]
#
#
#
# Downloading [onnx/special_tokens_map.json]:   0%|                                            | 0.00/964 [00:00<?, ?B/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   0%|                                         | 5.00M/2.11G [00:00<03:46, 9.97MB/s]
# Downloading [pytorch_model.bin]:   0%|                                            | 1.00M/2.12G [00:00<14:04, 2.69MB/s]
#
# Downloading [README.md]: 100%|████████████████████████████████████████████████████| 15.5k/15.5k [00:00<00:00, 40.2kB/s]
# Processing 29 items:  62%|████████████████████████████████████                      | 18.0/29.0 [00:01<00:00, 15.4it/s]
#
# Downloading [tokenizer.json]:   0%|                                                        | 0.00/16.3M [00:00<?, ?B/s]
#
#
#
#
# Downloading [sparse_linear.pt]: 100%|█████████████████████████████████████████████| 3.43k/3.43k [00:00<00:00, 12.2kB/s]
#
#
#
#
#
#
#
# Downloading [sparse_linear.pt]: 100%|█████████████████████████████████████████████| 3.43k/3.43k [00:00<00:00, 10.8kB/s]
#
#
#
#
#
# Downloading [onnx/tokenizer.json]:   0%|                                                   | 0.00/16.3M [00:00<?, ?B/s]
#
#
#
#
#
# Downloading [sentencepiece.bpe.model]:  21%|███████▊                              | 1.00M/4.83M [00:00<00:01, 2.39MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   0%|▏                                        | 7.00M/2.11G [00:00<03:35, 10.5MB/s]
# Downloading [pytorch_model.bin]:   0%|                                            | 4.00M/2.12G [00:00<04:26, 8.50MB/s]
#
#
#
#
#
#
#
# Downloading [onnx/sentencepiece.bpe.model]: 100%|█████████████████████████████████| 4.83M/4.83M [00:00<00:00, 8.74MB/s]
#
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   0%|▏                                        | 9.00M/2.11G [00:00<03:01, 12.4MB/s]
#
#
#
#
#
# Downloading [sentencepiece.bpe.model]:  83%|███████████████████████████████▍      | 4.00M/4.83M [00:00<00:00, 8.55MB/s]
#
#
#
#
#
#
#
# Downloading [onnx/tokenizer_config.json]:   0%|                                            | 0.00/1.15k [00:00<?, ?B/s]
#
#
# Downloading [special_tokens_map.json]: 100%|██████████████████████████████████████████| 964/964 [00:00<00:00, 2.59kB/s]
# Downloading [sentencepiece.bpe.model]: 100%|██████████████████████████████████████| 4.83M/4.83M [00:00<00:00, 7.84MB/s]
#
#
#
#
# Downloading [onnx/special_tokens_map.json]: 100%|█████████████████████████████████████| 964/964 [00:00<00:00, 2.46kB/s]
#
#
#
# Downloading [tokenizer_config.json]:   0%|                                                   | 0.00/444 [00:00<?, ?B/s]
# Downloading [pytorch_model.bin]:   0%|                                            | 6.00M/2.12G [00:00<04:14, 8.89MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   1%|▏                                        | 12.0M/2.11G [00:01<02:29, 15.1MB/s]
#
# Downloading [tokenizer.json]:   6%|██▉                                            | 1.00M/16.3M [00:00<00:06, 2.46MB/s]
#
#
#
#
# Downloading [onnx/tokenizer.json]:   6%|██▌                                       | 1.00M/16.3M [00:00<00:06, 2.65MB/s]
# Downloading [pytorch_model.bin]:   0%|▏                                           | 8.00M/2.12G [00:00<03:27, 10.9MB/s]
#
# Downloading [tokenizer.json]:  25%|███████████▌                                   | 4.00M/16.3M [00:00<00:01, 9.38MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   1%|▎                                        | 14.0M/2.11G [00:01<02:45, 13.6MB/s]
# Downloading [pytorch_model.bin]:   1%|▏                                           | 11.0M/2.12G [00:01<02:29, 15.2MB/s]
#
#
#
#
#
#
#
# Downloading [onnx/tokenizer_config.json]: 100%|███████████████████████████████████| 1.15k/1.15k [00:00<00:00, 3.28kB/s]
#
#
#
#
#
# Processing 29 items:  83%|████████████████████████████████████████████████          | 24.0/29.0 [00:01<00:00, 11.3it/s]
#
# Downloading [tokenizer.json]:  37%|█████████████████▎                             | 6.00M/16.3M [00:00<00:01, 10.7MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   1%|▎                                        | 16.0M/2.11G [00:01<02:47, 13.4MB/s]
#
#
# Downloading [tokenizer_config.json]: 100%|████████████████████████████████████████████| 444/444 [00:00<00:00, 1.14kB/s]
# Downloading [pytorch_model.bin]:   1%|▎                                           | 14.0M/2.12G [00:01<02:13, 16.9MB/s]
#
#
#
#
# Downloading [tokenizer_config.json]: 100%|████████████████████████████████████████████| 444/444 [00:00<00:00, 1.01kB/s]
#
#
# Downloading [tokenizer.json]:  55%|█████████████████████████▉                     | 9.00M/16.3M [00:00<00:00, 14.5MB/s]
#
#
#
#
# Downloading [onnx/tokenizer.json]:  49%|████████████████████▌                     | 8.00M/16.3M [00:00<00:00, 13.6MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   1%|▎                                        | 18.0M/2.11G [00:01<03:01, 12.4MB/s]
# Downloading [pytorch_model.bin]:   1%|▎                                           | 16.0M/2.12G [00:01<02:30, 14.9MB/s]
#
#
#
#
# Downloading [onnx/tokenizer.json]:  68%|████████████████████████████▎             | 11.0M/16.3M [00:00<00:00, 16.7MB/s]
#
# Downloading [tokenizer.json]:  67%|███████████████████████████████▋               | 11.0M/16.3M [00:01<00:00, 12.5MB/s]
# Downloading [pytorch_model.bin]:   1%|▎                                           | 18.0M/2.12G [00:01<02:33, 14.7MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   1%|▍                                        | 20.0M/2.11G [00:01<03:17, 11.4MB/s]
#
#
#
#
# Downloading [onnx/tokenizer.json]:  80%|█████████████████████████████████▌        | 13.0M/16.3M [00:01<00:00, 16.3MB/s]
# Downloading [pytorch_model.bin]:   1%|▍                                           | 20.0M/2.12G [00:01<02:21, 15.9MB/s]
#
# Downloading [tokenizer.json]:  80%|█████████████████████████████████████▍         | 13.0M/16.3M [00:01<00:00, 13.0MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   1%|▍                                        | 22.0M/2.11G [00:02<03:05, 12.1MB/s]
#
# Downloading [tokenizer.json]:  92%|███████████████████████████████████████████▏   | 15.0M/16.3M [00:01<00:00, 14.1MB/s]
#
#
#
#
# Downloading [onnx/tokenizer.json]: 100%|██████████████████████████████████████████| 16.3M/16.3M [00:01<00:00, 13.1MB/s]
#
# Downloading [tokenizer.json]: 100%|███████████████████████████████████████████████| 16.3M/16.3M [00:01<00:00, 12.1MB/s]
#
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   1%|▍                                        | 24.0M/2.11G [00:02<03:13, 11.6MB/s]
# Downloading [pytorch_model.bin]:   1%|▌                                           | 27.0M/2.12G [00:01<01:49, 20.5MB/s]
# Downloading [pytorch_model.bin]:   1%|▋                                           | 31.0M/2.12G [00:02<01:29, 24.9MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   1%|▍                                        | 26.0M/2.11G [00:02<03:22, 11.1MB/s]
# Downloading [pytorch_model.bin]:   2%|▋                                           | 34.0M/2.12G [00:02<01:30, 24.7MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   1%|▌                                        | 28.0M/2.11G [00:02<03:07, 11.9MB/s]
# Downloading [pytorch_model.bin]:   2%|▊                                           | 38.0M/2.12G [00:02<01:20, 27.7MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   1%|▌                                        | 30.0M/2.11G [00:02<02:52, 13.0MB/s]
# Downloading [pytorch_model.bin]:   2%|▊                                           | 41.0M/2.12G [00:02<01:29, 25.0MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   1%|▌                                        | 32.0M/2.11G [00:02<02:34, 14.5MB/s]
# Downloading [pytorch_model.bin]:   2%|▉                                           | 44.0M/2.12G [00:02<01:29, 25.0MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   2%|▋                                        | 35.0M/2.11G [00:02<02:04, 18.0MB/s]
# Downloading [pytorch_model.bin]:   2%|▉                                           | 47.0M/2.12G [00:02<01:25, 26.1MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   2%|▋                                        | 38.0M/2.11G [00:03<01:48, 20.5MB/s]
# Downloading [pytorch_model.bin]:   2%|█                                           | 51.0M/2.12G [00:02<01:18, 28.2MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   2%|▊                                        | 41.0M/2.11G [00:03<01:50, 20.2MB/s]
# Downloading [pytorch_model.bin]:   2%|█                                           | 54.0M/2.12G [00:02<01:17, 28.5MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   2%|▊                                        | 44.0M/2.11G [00:03<01:39, 22.4MB/s]
# Downloading [pytorch_model.bin]:   3%|█▏                                          | 57.0M/2.12G [00:03<01:22, 26.9MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   2%|▉                                        | 47.0M/2.11G [00:03<01:36, 22.9MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   2%|▉                                        | 50.0M/2.11G [00:03<01:58, 18.7MB/s]
# Downloading [pytorch_model.bin]:   3%|█▏                                          | 60.0M/2.12G [00:03<02:03, 17.9MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   2%|▉                                        | 52.0M/2.11G [00:03<02:05, 17.6MB/s]
# Downloading [pytorch_model.bin]:   3%|█▎                                          | 63.0M/2.12G [00:03<01:57, 18.8MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   2%|█                                        | 54.0M/2.11G [00:03<02:12, 16.6MB/s]
# Downloading [pytorch_model.bin]:   3%|█▎                                          | 66.0M/2.12G [00:03<01:53, 19.4MB/s]
# Downloading [pytorch_model.bin]:   3%|█▍                                          | 69.0M/2.12G [00:03<01:49, 20.1MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   3%|█                                        | 57.0M/2.11G [00:04<02:05, 17.5MB/s]
# Downloading [pytorch_model.bin]:   3%|█▍                                          | 72.0M/2.12G [00:03<01:46, 20.6MB/s]
# Downloading [pytorch_model.bin]:   4%|█▌                                          | 76.0M/2.12G [00:04<01:30, 24.2MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   3%|█                                        | 59.0M/2.11G [00:04<02:58, 12.3MB/s]
# Downloading [pytorch_model.bin]:   4%|█▌                                          | 79.0M/2.12G [00:04<01:33, 23.3MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   3%|█▏                                       | 62.0M/2.11G [00:04<02:22, 15.4MB/s]
# Downloading [pytorch_model.bin]:   4%|█▋                                          | 82.0M/2.12G [00:04<01:35, 22.9MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   3%|█▏                                       | 64.0M/2.11G [00:04<02:45, 13.3MB/s]
# Downloading [pytorch_model.bin]:   4%|█▋                                          | 86.0M/2.12G [00:04<01:26, 25.4MB/s]
# Downloading [pytorch_model.bin]:   4%|█▊                                          | 89.0M/2.12G [00:04<01:22, 26.3MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   3%|█▎                                       | 66.0M/2.11G [00:04<02:55, 12.5MB/s]
# Downloading [pytorch_model.bin]:   4%|█▊                                          | 92.0M/2.12G [00:04<01:32, 23.6MB/s]
# Downloading [pytorch_model.bin]:   4%|█▉                                          | 96.0M/2.12G [00:04<01:20, 26.8MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   3%|█▎                                       | 69.0M/2.11G [00:05<03:08, 11.7MB/s]
# Downloading [pytorch_model.bin]:   5%|██                                           | 100M/2.12G [00:05<01:14, 28.9MB/s]
# Downloading [pytorch_model.bin]:   5%|██▏                                          | 103M/2.12G [00:05<01:18, 27.5MB/s]
# Downloading [pytorch_model.bin]:   5%|██▏                                          | 107M/2.12G [00:05<01:12, 29.9MB/s]
# Downloading [pytorch_model.bin]:   5%|██▎                                          | 111M/2.12G [00:05<01:09, 31.2MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   3%|█▎                                       | 71.0M/2.11G [00:05<04:23, 8.33MB/s]
# Downloading [pytorch_model.bin]:   5%|██▍                                          | 115M/2.12G [00:05<01:11, 30.2MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   3%|█▍                                       | 74.0M/2.11G [00:05<03:40, 9.92MB/s]
# Downloading [pytorch_model.bin]:   5%|██▍                                          | 118M/2.12G [00:05<01:18, 27.5MB/s]
# Downloading [pytorch_model.bin]:   6%|██▌                                          | 121M/2.12G [00:05<01:15, 28.3MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   4%|█▍                                       | 76.0M/2.11G [00:06<03:25, 10.6MB/s]
# Downloading [pytorch_model.bin]:   6%|██▌                                          | 124M/2.12G [00:05<01:17, 27.7MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   4%|█▍                                       | 78.0M/2.11G [00:06<03:00, 12.1MB/s]
# Downloading [pytorch_model.bin]:   6%|██▋                                          | 127M/2.12G [00:06<01:28, 24.1MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   4%|█▌                                       | 80.0M/2.11G [00:06<03:00, 12.1MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   4%|█▌                                       | 82.0M/2.11G [00:06<02:49, 12.8MB/s]
# Downloading [pytorch_model.bin]:   6%|██▋                                          | 130M/2.12G [00:06<01:36, 22.2MB/s]
# Downloading [pytorch_model.bin]:   6%|██▊                                          | 133M/2.12G [00:06<01:29, 23.8MB/s]
# Downloading [pytorch_model.bin]:   6%|██▊                                          | 137M/2.12G [00:06<01:18, 27.2MB/s]
# Downloading [pytorch_model.bin]:   6%|██▉                                          | 140M/2.12G [00:06<01:19, 26.8MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   4%|█▌                                       | 84.0M/2.11G [00:06<04:22, 8.31MB/s]
# Downloading [pytorch_model.bin]:   7%|██▉                                          | 143M/2.12G [00:06<01:26, 24.5MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   4%|█▋                                       | 86.0M/2.11G [00:07<03:59, 9.08MB/s]
# Downloading [pytorch_model.bin]:   7%|███                                          | 146M/2.12G [00:06<01:29, 23.5MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   4%|█▋                                       | 88.0M/2.11G [00:07<03:20, 10.8MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   4%|█▋                                       | 90.0M/2.11G [00:07<02:52, 12.6MB/s]
# Downloading [pytorch_model.bin]:   7%|███                                          | 149M/2.12G [00:07<01:52, 18.8MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   4%|█▋                                       | 92.0M/2.11G [00:07<03:03, 11.9MB/s]
# Downloading [pytorch_model.bin]:   7%|███▏                                         | 151M/2.12G [00:07<02:27, 14.4MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   4%|█▊                                       | 94.0M/2.11G [00:07<03:06, 11.6MB/s]
# Downloading [pytorch_model.bin]:   7%|███▏                                         | 155M/2.12G [00:07<01:50, 19.1MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   4%|█▊                                       | 96.0M/2.11G [00:07<02:48, 12.8MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   5%|█▉                                       | 99.0M/2.11G [00:07<02:13, 16.2MB/s]
# Downloading [pytorch_model.bin]:   7%|███▎                                         | 158M/2.12G [00:07<01:55, 18.2MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   5%|█▉                                        | 101M/2.11G [00:08<02:06, 17.1MB/s]
# Downloading [pytorch_model.bin]:   7%|███▎                                         | 161M/2.12G [00:07<01:41, 20.7MB/s]
# Downloading [pytorch_model.bin]:   8%|███▍                                         | 165M/2.12G [00:07<01:25, 24.6MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   5%|██                                        | 104M/2.11G [00:08<01:51, 19.3MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   5%|██                                        | 106M/2.11G [00:08<01:51, 19.4MB/s]
# Downloading [pytorch_model.bin]:   8%|███▌                                         | 169M/2.12G [00:08<01:18, 26.6MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   5%|██                                        | 108M/2.11G [00:08<01:55, 18.7MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   5%|██▏                                       | 110M/2.11G [00:08<01:55, 18.7MB/s]
# Downloading [pytorch_model.bin]:   8%|███▌                                         | 172M/2.12G [00:08<01:43, 20.2MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   5%|██▏                                       | 112M/2.11G [00:08<01:56, 18.4MB/s]
# Downloading [pytorch_model.bin]:   8%|███▋                                         | 175M/2.12G [00:08<01:42, 20.3MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   5%|██▏                                       | 114M/2.11G [00:08<02:08, 16.8MB/s]
# Downloading [pytorch_model.bin]:   8%|███▋                                         | 178M/2.12G [00:08<01:39, 21.0MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   5%|██▎                                       | 116M/2.11G [00:08<02:11, 16.4MB/s]
# Downloading [pytorch_model.bin]:   8%|███▊                                         | 181M/2.12G [00:08<01:38, 21.2MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   5%|██▎                                       | 118M/2.11G [00:09<02:19, 15.3MB/s]
# Downloading [pytorch_model.bin]:   8%|███▊                                         | 184M/2.12G [00:08<01:29, 23.2MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   6%|██▎                                       | 120M/2.11G [00:09<02:37, 13.6MB/s]
# Downloading [pytorch_model.bin]:   9%|███▉                                         | 187M/2.12G [00:09<01:38, 21.0MB/s]
# Downloading [pytorch_model.bin]:   9%|███▉                                         | 190M/2.12G [00:09<01:34, 22.0MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   6%|██▎                                       | 122M/2.11G [00:09<03:01, 11.8MB/s]
# Downloading [pytorch_model.bin]:   9%|████                                         | 193M/2.12G [00:09<01:29, 23.2MB/s]
# Downloading [pytorch_model.bin]:   9%|████                                         | 198M/2.12G [00:09<01:10, 29.3MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   6%|██▍                                       | 124M/2.11G [00:09<03:03, 11.7MB/s]
# Downloading [pytorch_model.bin]:   9%|████▏                                        | 202M/2.12G [00:09<01:07, 30.7MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   6%|██▍                                       | 126M/2.11G [00:09<02:43, 13.1MB/s]
# Downloading [pytorch_model.bin]:  10%|████▎                                        | 206M/2.12G [00:09<01:10, 29.3MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   6%|██▍                                       | 128M/2.11G [00:10<02:42, 13.2MB/s]
# Downloading [pytorch_model.bin]:  10%|████▎                                        | 210M/2.12G [00:09<01:06, 30.7MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   6%|██▌                                       | 131M/2.11G [00:10<02:35, 13.7MB/s]
# Downloading [pytorch_model.bin]:  10%|████▍                                        | 214M/2.12G [00:09<01:15, 27.2MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   6%|██▌                                       | 133M/2.11G [00:10<02:29, 14.2MB/s]
# Downloading [pytorch_model.bin]:  10%|████▌                                        | 217M/2.12G [00:10<01:18, 26.1MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   6%|██▋                                       | 136M/2.11G [00:10<02:08, 16.6MB/s]
# Downloading [pytorch_model.bin]:  10%|████▌                                        | 221M/2.12G [00:10<01:11, 28.5MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   6%|██▋                                       | 138M/2.11G [00:10<02:09, 16.4MB/s]
# Downloading [pytorch_model.bin]:  10%|████▋                                        | 225M/2.12G [00:10<01:05, 30.9MB/s]
# Downloading [pytorch_model.bin]:  11%|████▊                                        | 230M/2.12G [00:10<00:57, 35.4MB/s]
# Downloading [pytorch_model.bin]:  11%|████▉                                        | 235M/2.12G [00:10<00:54, 36.9MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   6%|██▋                                       | 140M/2.11G [00:10<03:01, 11.7MB/s]
# Downloading [pytorch_model.bin]:  11%|████▉                                        | 239M/2.12G [00:10<01:11, 28.1MB/s]
# Downloading [pytorch_model.bin]:  11%|█████                                        | 243M/2.12G [00:10<01:07, 30.0MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   7%|██▊                                       | 142M/2.11G [00:11<04:06, 8.60MB/s]
# Downloading [pytorch_model.bin]:  11%|█████▏                                       | 247M/2.12G [00:11<01:06, 30.4MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   7%|██▊                                       | 144M/2.11G [00:11<03:50, 9.19MB/s]
# Downloading [pytorch_model.bin]:  12%|█████▏                                       | 251M/2.12G [00:11<01:13, 27.4MB/s]
# Downloading [pytorch_model.bin]:  12%|█████▎                                       | 255M/2.12G [00:11<01:08, 29.4MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   7%|██▊                                       | 146M/2.11G [00:11<03:43, 9.46MB/s]
# Downloading [pytorch_model.bin]:  12%|█████▍                                       | 259M/2.12G [00:11<01:05, 30.5MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   7%|██▉                                       | 148M/2.11G [00:11<03:07, 11.3MB/s]
# Downloading [pytorch_model.bin]:  12%|█████▍                                       | 263M/2.12G [00:11<01:01, 32.6MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   7%|██▉                                       | 150M/2.11G [00:11<02:43, 12.9MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   7%|██▉                                       | 153M/2.11G [00:12<02:08, 16.4MB/s]
# Downloading [pytorch_model.bin]:  12%|█████▌                                       | 267M/2.12G [00:11<01:08, 29.1MB/s]
# Downloading [pytorch_model.bin]:  12%|█████▌                                       | 270M/2.12G [00:11<01:08, 29.1MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   7%|███                                       | 156M/2.11G [00:12<02:00, 17.5MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   7%|███                                       | 158M/2.11G [00:12<02:01, 17.3MB/s]
# Downloading [pytorch_model.bin]:  13%|█████▋                                       | 273M/2.12G [00:12<01:14, 26.5MB/s]
# Downloading [pytorch_model.bin]:  13%|█████▋                                       | 276M/2.12G [00:12<01:17, 25.6MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   7%|███                                       | 160M/2.11G [00:12<02:18, 15.1MB/s]
# Downloading [pytorch_model.bin]:  13%|█████▊                                       | 280M/2.12G [00:12<01:12, 27.3MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   7%|███▏                                      | 162M/2.11G [00:12<02:36, 13.4MB/s]
# Downloading [pytorch_model.bin]:  13%|█████▉                                       | 285M/2.12G [00:12<01:02, 31.5MB/s]
# Downloading [pytorch_model.bin]:  13%|██████                                       | 289M/2.12G [00:12<00:57, 34.0MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   8%|███▏                                      | 164M/2.11G [00:12<02:35, 13.5MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   8%|███▏                                      | 166M/2.11G [00:13<02:36, 13.4MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   8%|███▎                                      | 168M/2.11G [00:13<02:43, 12.8MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   8%|███▎                                      | 171M/2.11G [00:13<02:09, 16.1MB/s]
# Downloading [pytorch_model.bin]:  14%|██████                                       | 293M/2.12G [00:13<01:53, 17.3MB/s]
# Downloading [pytorch_model.bin]:  14%|██████▏                                      | 296M/2.12G [00:13<01:45, 18.6MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   8%|███▍                                      | 174M/2.11G [00:13<01:59, 17.4MB/s]
# Downloading [pytorch_model.bin]:  14%|██████▏                                      | 299M/2.12G [00:13<01:38, 19.8MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   8%|███▍                                      | 176M/2.11G [00:13<02:27, 14.1MB/s]
# Downloading [pytorch_model.bin]:  14%|██████▎                                      | 303M/2.12G [00:13<01:24, 23.0MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   8%|███▍                                      | 178M/2.11G [00:13<02:15, 15.3MB/s]
# Processing 29 items:  93%|██████████████████████████████████████████████████████    | 27.0/29.0 [00:14<00:00, 6.50it/s]
# Downloading [pytorch_model.bin]:  14%|██████▍                                      | 310M/2.12G [00:13<01:11, 27.1MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   8%|███▍                                      | 180M/2.11G [00:14<02:54, 11.9MB/s]
# Downloading [pytorch_model.bin]:  14%|██████▌                                      | 313M/2.12G [00:13<01:27, 22.2MB/s]
# Downloading [pytorch_model.bin]:  15%|██████▌                                      | 316M/2.12G [00:14<01:26, 22.4MB/s]
# Downloading [pytorch_model.bin]:  15%|██████▋                                      | 320M/2.12G [00:14<01:13, 26.4MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   8%|███▌                                      | 182M/2.11G [00:14<03:40, 9.40MB/s]
# Downloading [pytorch_model.bin]:  15%|██████▋                                      | 324M/2.12G [00:14<01:11, 26.9MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   9%|███▌                                      | 184M/2.11G [00:14<03:28, 9.93MB/s]
# Downloading [pytorch_model.bin]:  15%|██████▊                                      | 327M/2.12G [00:14<01:16, 25.2MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   9%|███▌                                      | 186M/2.11G [00:14<03:11, 10.8MB/s]
# Downloading [pytorch_model.bin]:  15%|██████▊                                      | 330M/2.12G [00:14<01:12, 26.5MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   9%|███▋                                      | 189M/2.11G [00:14<02:36, 13.2MB/s]
# Downloading [pytorch_model.bin]:  15%|██████▉                                      | 333M/2.12G [00:14<01:22, 23.2MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   9%|███▋                                      | 191M/2.11G [00:15<02:40, 12.8MB/s]
# Downloading [pytorch_model.bin]:  16%|██████▉                                      | 336M/2.12G [00:14<01:20, 24.0MB/s]
# Downloading [pytorch_model.bin]:  16%|███████                                      | 340M/2.12G [00:14<01:10, 27.2MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   9%|███▋                                      | 193M/2.11G [00:15<02:55, 11.8MB/s]
# Downloading [pytorch_model.bin]:  16%|███████▏                                     | 345M/2.12G [00:15<01:09, 27.5MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   9%|███▊                                      | 195M/2.11G [00:15<02:37, 13.1MB/s]
# Downloading [pytorch_model.bin]:  16%|███████▏                                     | 348M/2.12G [00:15<01:17, 24.7MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   9%|███▊                                      | 198M/2.11G [00:15<02:15, 15.2MB/s]
# Downloading [pytorch_model.bin]:  16%|███████▎                                     | 351M/2.12G [00:15<01:23, 22.7MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   9%|███▉                                      | 200M/2.11G [00:15<02:27, 14.0MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   9%|███▉                                      | 202M/2.11G [00:15<02:17, 15.0MB/s]
# Downloading [pytorch_model.bin]:  16%|███████▎                                     | 354M/2.12G [00:15<01:31, 20.8MB/s]
# Downloading [pytorch_model.bin]:  17%|███████▍                                     | 358M/2.12G [00:15<01:18, 24.2MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:   9%|███▉                                      | 204M/2.11G [00:16<02:41, 12.7MB/s]
# Downloading [pytorch_model.bin]:  17%|███████▌                                     | 361M/2.12G [00:15<01:17, 24.5MB/s]
# Downloading [pytorch_model.bin]:  17%|███████▌                                     | 364M/2.12G [00:16<01:17, 24.4MB/s]
# Downloading [pytorch_model.bin]:  17%|███████▋                                     | 368M/2.12G [00:16<01:06, 28.2MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  10%|████                                      | 206M/2.11G [00:16<03:56, 8.66MB/s]
# Downloading [pytorch_model.bin]:  17%|███████▋                                     | 373M/2.12G [00:16<01:00, 31.0MB/s]
# Downloading [pytorch_model.bin]:  17%|███████▊                                     | 377M/2.12G [00:16<00:59, 31.6MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  10%|████                                      | 209M/2.11G [00:16<03:10, 10.8MB/s]
# Downloading [pytorch_model.bin]:  18%|███████▉                                     | 381M/2.12G [00:16<01:09, 27.0MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  10%|████                                      | 211M/2.11G [00:16<03:05, 11.0MB/s]
# Downloading [pytorch_model.bin]:  18%|███████▉                                     | 384M/2.12G [00:16<01:16, 24.4MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  10%|████▏                                     | 213M/2.11G [00:17<03:17, 10.4MB/s]
# Downloading [pytorch_model.bin]:  18%|████████                                     | 387M/2.12G [00:16<01:14, 25.0MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  10%|████▏                                     | 215M/2.11G [00:17<03:04, 11.1MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  10%|████▏                                     | 217M/2.11G [00:17<02:43, 12.5MB/s]
# Downloading [pytorch_model.bin]:  18%|████████                                     | 390M/2.12G [00:17<02:06, 14.7MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  10%|████▎                                     | 219M/2.11G [00:17<03:19, 10.2MB/s]
# Downloading [pytorch_model.bin]:  18%|████████▏                                    | 395M/2.12G [00:17<01:34, 19.6MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  10%|████▎                                     | 221M/2.11G [00:17<03:14, 10.5MB/s]
# Downloading [pytorch_model.bin]:  18%|████████▎                                    | 398M/2.12G [00:17<01:43, 18.0MB/s]
# Downloading [pytorch_model.bin]:  19%|████████▎                                    | 402M/2.12G [00:17<01:26, 21.4MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  10%|████▎                                     | 223M/2.11G [00:18<03:17, 10.3MB/s]
# Downloading [pytorch_model.bin]:  19%|████████▍                                    | 405M/2.12G [00:17<01:21, 22.6MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  10%|████▎                                     | 225M/2.11G [00:18<03:11, 10.6MB/s]
# Downloading [pytorch_model.bin]:  19%|████████▌                                    | 410M/2.12G [00:18<01:09, 26.7MB/s]
# Downloading [pytorch_model.bin]:  19%|████████▌                                    | 414M/2.12G [00:18<01:01, 29.7MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  11%|████▍                                     | 227M/2.11G [00:18<03:13, 10.5MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  11%|████▍                                     | 230M/2.11G [00:18<02:26, 13.9MB/s]
# Downloading [pytorch_model.bin]:  19%|████████▋                                    | 418M/2.12G [00:18<01:08, 26.9MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  11%|████▌                                     | 232M/2.11G [00:18<02:13, 15.1MB/s]
# Downloading [pytorch_model.bin]:  19%|████████▋                                    | 421M/2.12G [00:18<01:20, 22.7MB/s]
# Downloading [pytorch_model.bin]:  20%|████████▊                                    | 425M/2.12G [00:18<01:09, 26.2MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  11%|████▌                                     | 234M/2.11G [00:18<02:43, 12.4MB/s]
# Downloading [pytorch_model.bin]:  20%|████████▉                                    | 429M/2.12G [00:18<01:03, 28.7MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  11%|████▌                                     | 237M/2.11G [00:19<02:30, 13.4MB/s]
# Downloading [pytorch_model.bin]:  20%|████████▉                                    | 433M/2.12G [00:18<00:59, 30.4MB/s]
# Downloading [pytorch_model.bin]:  20%|█████████                                    | 437M/2.12G [00:19<01:03, 28.6MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  11%|████▋                                     | 240M/2.11G [00:19<02:28, 13.6MB/s]
# Downloading [pytorch_model.bin]:  20%|█████████▏                                   | 440M/2.12G [00:19<01:08, 26.5MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  11%|████▋                                     | 242M/2.11G [00:19<02:20, 14.4MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  11%|████▋                                     | 244M/2.11G [00:19<02:13, 15.1MB/s]
# Downloading [pytorch_model.bin]:  20%|█████████▏                                   | 444M/2.12G [00:19<01:05, 27.7MB/s]
# Downloading [pytorch_model.bin]:  21%|█████████▎                                   | 447M/2.12G [00:19<01:05, 27.6MB/s]
# Downloading [pytorch_model.bin]:  21%|█████████▎                                   | 450M/2.12G [00:19<01:07, 26.7MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  11%|████▊                                     | 246M/2.11G [00:19<02:44, 12.2MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  11%|████▊                                     | 248M/2.11G [00:20<02:28, 13.5MB/s]
# Downloading [pytorch_model.bin]:  21%|█████████▍                                   | 453M/2.12G [00:19<01:12, 24.7MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  12%|████▊                                     | 250M/2.11G [00:20<02:20, 14.3MB/s]
# Downloading [pytorch_model.bin]:  21%|█████████▍                                   | 456M/2.12G [00:19<01:08, 26.3MB/s]
# Downloading [pytorch_model.bin]:  21%|█████████▌                                   | 459M/2.12G [00:19<01:06, 26.8MB/s]
# Downloading [pytorch_model.bin]:  21%|█████████▌                                   | 462M/2.12G [00:20<01:09, 25.5MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  12%|████▉                                     | 252M/2.11G [00:20<03:00, 11.1MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  12%|████▉                                     | 254M/2.11G [00:20<03:03, 10.9MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  12%|████▉                                     | 256M/2.11G [00:20<02:39, 12.5MB/s]
# Downloading [pytorch_model.bin]:  21%|█████████▋                                   | 465M/2.12G [00:20<02:16, 13.0MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  12%|█████                                     | 258M/2.11G [00:21<03:09, 10.5MB/s]
# Downloading [pytorch_model.bin]:  22%|█████████▋                                   | 469M/2.12G [00:20<01:49, 16.3MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  12%|█████                                     | 260M/2.11G [00:21<03:04, 10.8MB/s]
# Downloading [pytorch_model.bin]:  22%|█████████▊                                   | 472M/2.12G [00:20<01:49, 16.2MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  12%|█████                                     | 262M/2.11G [00:21<02:40, 12.4MB/s]
# Downloading [pytorch_model.bin]:  22%|█████████▊                                   | 475M/2.12G [00:21<01:35, 18.6MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  12%|█████▏                                    | 264M/2.11G [00:21<02:22, 13.9MB/s]
# Downloading [pytorch_model.bin]:  22%|█████████▉                                   | 479M/2.12G [00:21<01:27, 20.2MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  12%|█████▏                                    | 267M/2.11G [00:21<02:04, 15.9MB/s]
# Downloading [pytorch_model.bin]:  22%|██████████                                   | 482M/2.12G [00:21<01:25, 20.6MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  12%|█████▏                                    | 269M/2.11G [00:21<02:20, 14.1MB/s]
# Downloading [pytorch_model.bin]:  22%|██████████                                   | 486M/2.12G [00:21<01:11, 24.8MB/s]
# Downloading [pytorch_model.bin]:  23%|██████████▏                                  | 489M/2.12G [00:21<01:07, 25.9MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  13%|█████▎                                    | 271M/2.11G [00:21<02:38, 12.5MB/s]
# Downloading [pytorch_model.bin]:  23%|██████████▎                                  | 494M/2.12G [00:21<00:55, 31.4MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  13%|█████▎                                    | 274M/2.11G [00:22<02:10, 15.2MB/s]
# Downloading [pytorch_model.bin]:  23%|██████████▎                                  | 498M/2.12G [00:21<00:58, 29.9MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  13%|█████▎                                    | 276M/2.11G [00:22<02:05, 15.7MB/s]
# Downloading [pytorch_model.bin]:  23%|██████████▍                                  | 502M/2.12G [00:22<01:00, 28.7MB/s]
# Downloading [pytorch_model.bin]:  23%|██████████▍                                  | 505M/2.12G [00:22<01:05, 26.4MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  13%|█████▍                                    | 278M/2.11G [00:22<03:14, 10.1MB/s]
# Downloading [pytorch_model.bin]:  23%|██████████▌                                  | 508M/2.12G [00:22<01:13, 23.6MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  13%|█████▍                                    | 280M/2.11G [00:22<02:51, 11.5MB/s]
# Downloading [pytorch_model.bin]:  24%|██████████▌                                  | 511M/2.12G [00:22<01:16, 22.8MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  13%|█████▍                                    | 282M/2.11G [00:22<02:46, 11.8MB/s]
# Downloading [pytorch_model.bin]:  24%|██████████▋                                  | 514M/2.12G [00:22<01:16, 22.6MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  13%|█████▌                                    | 284M/2.11G [00:23<02:43, 12.1MB/s]
# Downloading [pytorch_model.bin]:  24%|██████████▋                                  | 517M/2.12G [00:22<01:20, 21.4MB/s]
# Downloading [pytorch_model.bin]:  24%|██████████▊                                  | 520M/2.12G [00:22<01:23, 20.6MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  13%|█████▌                                    | 286M/2.11G [00:23<03:07, 10.5MB/s]
# Downloading [pytorch_model.bin]:  24%|██████████▊                                  | 523M/2.12G [00:23<01:21, 21.0MB/s]
# Downloading [pytorch_model.bin]:  24%|██████████▉                                  | 526M/2.12G [00:23<01:26, 19.9MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  13%|█████▌                                    | 288M/2.11G [00:23<03:36, 9.08MB/s]
# Downloading [pytorch_model.bin]:  24%|██████████▉                                  | 528M/2.12G [00:23<01:28, 19.3MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  13%|█████▋                                    | 290M/2.11G [00:23<03:06, 10.5MB/s]
# Downloading [pytorch_model.bin]:  24%|███████████                                  | 530M/2.12G [00:23<01:28, 19.4MB/s]
# Downloading [pytorch_model.bin]:  25%|███████████                                  | 533M/2.12G [00:23<01:26, 19.7MB/s]
# Downloading [pytorch_model.bin]:  25%|███████████                                  | 535M/2.12G [00:23<01:27, 19.5MB/s]
# Downloading [pytorch_model.bin]:  25%|███████████▏                                 | 537M/2.12G [00:23<01:26, 19.8MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  14%|█████▋                                    | 292M/2.11G [00:24<04:06, 7.96MB/s]
# Downloading [pytorch_model.bin]:  25%|███████████▏                                 | 539M/2.12G [00:24<01:26, 19.8MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  14%|█████▋                                    | 293M/2.11G [00:24<04:01, 8.11MB/s]
# Downloading [pytorch_model.bin]:  25%|███████████▏                                 | 541M/2.12G [00:24<01:26, 19.7MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  14%|█████▋                                    | 294M/2.11G [00:24<03:54, 8.34MB/s]
# Downloading [pytorch_model.bin]:  25%|███████████▎                                 | 543M/2.12G [00:24<01:28, 19.3MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  14%|█████▋                                    | 295M/2.11G [00:24<04:22, 7.45MB/s]
# Downloading [pytorch_model.bin]:  25%|███████████▎                                 | 545M/2.12G [00:24<01:30, 18.8MB/s]
# Downloading [pytorch_model.bin]:  25%|███████████▍                                 | 548M/2.12G [00:24<01:26, 19.6MB/s]
# Downloading [pytorch_model.bin]:  25%|███████████▍                                 | 550M/2.12G [00:24<01:28, 19.2MB/s]
# Downloading [pytorch_model.bin]:  26%|███████████▍                                 | 553M/2.12G [00:24<01:24, 19.9MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  14%|█████▊                                    | 297M/2.11G [00:25<05:21, 6.08MB/s]
# Downloading [pytorch_model.bin]:  26%|███████████▌                                 | 555M/2.12G [00:24<01:25, 19.9MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  14%|█████▊                                    | 298M/2.11G [00:25<05:05, 6.40MB/s]
# Downloading [pytorch_model.bin]:  26%|███████████▌                                 | 557M/2.12G [00:24<01:24, 20.0MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  14%|█████▊                                    | 299M/2.11G [00:25<04:40, 6.96MB/s]
# Downloading [pytorch_model.bin]:  26%|███████████▌                                 | 559M/2.12G [00:25<01:23, 20.2MB/s]
# Downloading [pytorch_model.bin]:  26%|███████████▋                                 | 561M/2.12G [00:25<01:29, 18.8MB/s]
# Downloading [pytorch_model.bin]:  26%|███████████▋                                 | 563M/2.12G [00:25<01:36, 17.4MB/s]
#
#
#
#
#
#
# ...
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  89%|████████████████████████████████████▋    | 1.89G/2.11G [02:58<00:27, 8.80MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  90%|████████████████████████████████████▋    | 1.89G/2.11G [02:59<00:24, 9.65MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  90%|████████████████████████████████████▋    | 1.89G/2.11G [02:59<00:21, 11.0MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  90%|████████████████████████████████████▊    | 1.89G/2.11G [02:59<00:19, 12.3MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  90%|████████████████████████████████████▊    | 1.90G/2.11G [02:59<00:20, 11.5MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  90%|████████████████████████████████████▊    | 1.90G/2.11G [02:59<00:20, 11.4MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  90%|████████████████████████████████████▉    | 1.90G/2.11G [03:00<00:25, 9.06MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  90%|████████████████████████████████████▉    | 1.90G/2.11G [03:00<00:25, 9.01MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  90%|████████████████████████████████████▉    | 1.90G/2.11G [03:00<00:35, 6.37MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  90%|████████████████████████████████████▉    | 1.90G/2.11G [03:01<00:50, 4.44MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  90%|████████████████████████████████████▉    | 1.90G/2.11G [03:01<01:22, 2.69MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  90%|████████████████████████████████████▉    | 1.90G/2.11G [03:02<01:10, 3.14MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  90%|█████████████████████████████████████    | 1.91G/2.11G [03:02<00:46, 4.71MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  90%|█████████████████████████████████████    | 1.91G/2.11G [03:02<00:41, 5.29MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  90%|█████████████████████████████████████    | 1.91G/2.11G [03:02<00:31, 6.88MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  91%|█████████████████████████████████████    | 1.91G/2.11G [03:02<00:25, 8.46MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  91%|█████████████████████████████████████▏   | 1.91G/2.11G [03:02<00:22, 9.59MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  91%|█████████████████████████████████████▏   | 1.92G/2.11G [03:02<00:18, 11.1MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  91%|█████████████████████████████████████▏   | 1.92G/2.11G [03:03<00:16, 12.6MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  91%|█████████████████████████████████████▎   | 1.92G/2.11G [03:03<00:16, 12.3MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  91%|█████████████████████████████████████▎   | 1.92G/2.11G [03:03<00:16, 12.1MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  91%|█████████████████████████████████████▎   | 1.92G/2.11G [03:03<00:14, 13.6MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  91%|█████████████████████████████████████▍   | 1.92G/2.11G [03:03<00:20, 9.54MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  91%|█████████████████████████████████████▍   | 1.93G/2.11G [03:03<00:17, 11.3MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  91%|█████████████████████████████████████▍   | 1.93G/2.11G [03:04<00:15, 12.5MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  91%|█████████████████████████████████████▍   | 1.93G/2.11G [03:04<00:21, 8.82MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  92%|█████████████████████████████████████▌   | 1.93G/2.11G [03:04<00:26, 7.27MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  92%|█████████████████████████████████████▌   | 1.93G/2.11G [03:05<00:23, 8.13MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  92%|█████████████████████████████████████▌   | 1.94G/2.11G [03:05<00:22, 8.46MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  92%|█████████████████████████████████████▌   | 1.94G/2.11G [03:05<00:21, 8.64MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  92%|█████████████████████████████████████▋   | 1.94G/2.11G [03:05<00:17, 10.8MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  92%|█████████████████████████████████████▋   | 1.94G/2.11G [03:05<00:16, 10.8MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  92%|█████████████████████████████████████▋   | 1.94G/2.11G [03:05<00:19, 9.33MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  92%|█████████████████████████████████████▊   | 1.94G/2.11G [03:06<00:17, 10.4MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  92%|█████████████████████████████████████▊   | 1.95G/2.11G [03:06<00:22, 8.00MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  92%|█████████████████████████████████████▊   | 1.95G/2.11G [03:06<00:19, 8.84MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  92%|█████████████████████████████████████▊   | 1.95G/2.11G [03:06<00:19, 9.02MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  92%|█████████████████████████████████████▊   | 1.95G/2.11G [03:06<00:21, 7.88MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  92%|█████████████████████████████████████▉   | 1.95G/2.11G [03:07<00:19, 8.91MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  93%|█████████████████████████████████████▉   | 1.95G/2.11G [03:07<00:16, 10.3MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  93%|█████████████████████████████████████▉   | 1.96G/2.11G [03:07<00:14, 11.5MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  93%|██████████████████████████████████████   | 1.96G/2.11G [03:07<00:13, 11.8MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  93%|██████████████████████████████████████   | 1.96G/2.11G [03:07<00:13, 12.1MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  93%|██████████████████████████████████████   | 1.96G/2.11G [03:07<00:13, 12.2MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  93%|██████████████████████████████████████▏  | 1.96G/2.11G [03:08<00:11, 13.6MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  93%|██████████████████████████████████████▏  | 1.97G/2.11G [03:08<00:13, 11.6MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  93%|██████████████████████████████████████▏  | 1.97G/2.11G [03:08<00:15, 10.2MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  93%|██████████████████████████████████████▎  | 1.97G/2.11G [03:08<00:14, 10.2MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  93%|██████████████████████████████████████▎  | 1.97G/2.11G [03:08<00:13, 11.2MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  93%|██████████████████████████████████████▎  | 1.97G/2.11G [03:08<00:11, 12.5MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  94%|██████████████████████████████████████▎  | 1.98G/2.11G [03:09<00:11, 12.8MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  94%|██████████████████████████████████████▍  | 1.98G/2.11G [03:09<00:11, 12.3MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  94%|██████████████████████████████████████▍  | 1.98G/2.11G [03:09<00:10, 13.5MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  94%|██████████████████████████████████████▍  | 1.98G/2.11G [03:09<00:10, 13.1MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  94%|██████████████████████████████████████▌  | 1.98G/2.11G [03:09<00:11, 11.5MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  94%|██████████████████████████████████████▌  | 1.99G/2.11G [03:09<00:10, 12.7MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  94%|██████████████████████████████████████▌  | 1.99G/2.11G [03:10<00:11, 12.0MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  94%|██████████████████████████████████████▋  | 1.99G/2.11G [03:10<00:11, 11.4MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  94%|██████████████████████████████████████▋  | 1.99G/2.11G [03:10<00:10, 12.4MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  94%|██████████████████████████████████████▋  | 1.99G/2.11G [03:10<00:12, 9.92MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  95%|██████████████████████████████████████▋  | 2.00G/2.11G [03:11<00:12, 9.98MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  95%|██████████████████████████████████████▊  | 2.00G/2.11G [03:11<00:15, 8.10MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  95%|██████████████████████████████████████▊  | 2.00G/2.11G [03:11<00:12, 9.59MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  95%|██████████████████████████████████████▊  | 2.00G/2.11G [03:12<00:19, 6.22MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  95%|██████████████████████████████████████▉  | 2.00G/2.11G [03:12<00:26, 4.42MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  95%|██████████████████████████████████████▉  | 2.00G/2.11G [03:12<00:25, 4.60MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  95%|██████████████████████████████████████▉  | 2.00G/2.11G [03:13<00:17, 6.44MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  95%|██████████████████████████████████████▉  | 2.01G/2.11G [03:13<00:14, 7.75MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  95%|███████████████████████████████████████  | 2.01G/2.11G [03:13<00:11, 9.54MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  95%|███████████████████████████████████████  | 2.01G/2.11G [03:13<00:09, 11.1MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  95%|███████████████████████████████████████  | 2.01G/2.11G [03:13<00:08, 12.6MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  95%|███████████████████████████████████████▏ | 2.01G/2.11G [03:13<00:07, 13.7MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  96%|███████████████████████████████████████▏ | 2.02G/2.11G [03:13<00:06, 15.1MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  96%|███████████████████████████████████████▏ | 2.02G/2.11G [03:13<00:06, 15.7MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  96%|███████████████████████████████████████▏ | 2.02G/2.11G [03:13<00:06, 15.9MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  96%|███████████████████████████████████████▎ | 2.02G/2.11G [03:14<00:07, 13.6MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  96%|███████████████████████████████████████▎ | 2.02G/2.11G [03:14<00:06, 14.3MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  96%|███████████████████████████████████████▎ | 2.03G/2.11G [03:14<00:06, 13.2MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  96%|███████████████████████████████████████▍ | 2.03G/2.11G [03:14<00:07, 12.5MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  96%|███████████████████████████████████████▍ | 2.03G/2.11G [03:14<00:06, 12.7MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  96%|███████████████████████████████████████▍ | 2.03G/2.11G [03:15<00:06, 13.1MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  96%|███████████████████████████████████████▌ | 2.03G/2.11G [03:15<00:07, 11.5MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  96%|███████████████████████████████████████▌ | 2.04G/2.11G [03:15<00:08, 9.22MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  96%|███████████████████████████████████████▌ | 2.04G/2.11G [03:15<00:08, 8.93MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  97%|███████████████████████████████████████▌ | 2.04G/2.11G [03:16<00:10, 7.23MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  97%|███████████████████████████████████████▌ | 2.04G/2.11G [03:16<00:09, 7.67MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  97%|███████████████████████████████████████▋ | 2.04G/2.11G [03:16<00:10, 7.42MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  97%|███████████████████████████████████████▋ | 2.04G/2.11G [03:16<00:11, 6.23MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  97%|███████████████████████████████████████▋ | 2.04G/2.11G [03:16<00:11, 6.15MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  97%|███████████████████████████████████████▋ | 2.04G/2.11G [03:16<00:09, 7.77MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  97%|███████████████████████████████████████▊ | 2.05G/2.11G [03:17<00:07, 8.89MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  97%|███████████████████████████████████████▊ | 2.05G/2.11G [03:17<00:06, 9.84MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  97%|███████████████████████████████████████▊ | 2.05G/2.11G [03:17<00:06, 9.80MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  97%|███████████████████████████████████████▊ | 2.05G/2.11G [03:17<00:06, 9.36MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  97%|███████████████████████████████████████▊ | 2.05G/2.11G [03:17<00:05, 10.5MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  97%|███████████████████████████████████████▉ | 2.05G/2.11G [03:17<00:05, 11.5MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  97%|███████████████████████████████████████▉ | 2.06G/2.11G [03:18<00:05, 11.7MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  98%|███████████████████████████████████████▉ | 2.06G/2.11G [03:18<00:05, 11.1MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  98%|████████████████████████████████████████ | 2.06G/2.11G [03:18<00:04, 12.4MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  98%|████████████████████████████████████████ | 2.06G/2.11G [03:19<00:09, 5.70MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  98%|████████████████████████████████████████ | 2.06G/2.11G [03:19<00:10, 4.94MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  98%|████████████████████████████████████████ | 2.06G/2.11G [03:20<00:12, 3.96MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  98%|████████████████████████████████████████▏| 2.07G/2.11G [03:20<00:08, 5.45MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  98%|████████████████████████████████████████▏| 2.07G/2.11G [03:20<00:05, 7.65MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  98%|████████████████████████████████████████▏| 2.07G/2.11G [03:20<00:05, 8.27MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  98%|████████████████████████████████████████▎| 2.07G/2.11G [03:20<00:04, 9.89MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  98%|████████████████████████████████████████▎| 2.08G/2.11G [03:20<00:03, 10.7MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  98%|████████████████████████████████████████▎| 2.08G/2.11G [03:20<00:03, 11.2MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  98%|████████████████████████████████████████▍| 2.08G/2.11G [03:21<00:02, 12.0MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  99%|████████████████████████████████████████▍| 2.08G/2.11G [03:21<00:02, 13.5MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  99%|████████████████████████████████████████▍| 2.08G/2.11G [03:21<00:02, 14.3MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  99%|████████████████████████████████████████▍| 2.08G/2.11G [03:21<00:01, 15.1MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  99%|████████████████████████████████████████▌| 2.09G/2.11G [03:21<00:01, 15.7MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  99%|████████████████████████████████████████▌| 2.09G/2.11G [03:21<00:01, 15.9MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  99%|████████████████████████████████████████▌| 2.09G/2.11G [03:21<00:01, 14.3MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  99%|████████████████████████████████████████▋| 2.09G/2.11G [03:22<00:01, 14.8MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  99%|████████████████████████████████████████▋| 2.09G/2.11G [03:22<00:01, 15.8MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  99%|████████████████████████████████████████▋| 2.10G/2.11G [03:22<00:01, 14.3MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]:  99%|████████████████████████████████████████▊| 2.10G/2.11G [03:22<00:00, 13.6MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]: 100%|████████████████████████████████████████▊| 2.10G/2.11G [03:22<00:00, 14.2MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]: 100%|████████████████████████████████████████▊| 2.10G/2.11G [03:22<00:00, 14.8MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]: 100%|████████████████████████████████████████▊| 2.10G/2.11G [03:22<00:00, 14.1MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]: 100%|████████████████████████████████████████▉| 2.11G/2.11G [03:23<00:00, 14.3MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]: 100%|████████████████████████████████████████▉| 2.11G/2.11G [03:23<00:00, 15.5MB/s]
#
#
#
#
#
#
# Downloading [onnx/model.onnx_data]: 100%|█████████████████████████████████████████| 2.11G/2.11G [03:23<00:00, 11.1MB/s]
# Processing 29 items: 100%|██████████████████████████████████████████████████████████| 29.0/29.0 [03:23<00:00, 7.03s/it]
# 2025-04-18 14:54:52,069 - modelscope - INFO - Download model 'BAAI/bge-m3' successfully.

# %%
# !pip install FlagEmbedding
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: FlagEmbedding in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (1.3.4)
# Requirement already satisfied: torch>=1.6.0 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from FlagEmbedding) (2.6.0)
# Requirement already satisfied: transformers>=4.44.2 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from FlagEmbedding) (4.50.3)
# Requirement already satisfied: datasets>=2.19.0 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from FlagEmbedding) (3.5.0)
# Requirement already satisfied: accelerate>=0.20.1 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from FlagEmbedding) (1.6.0)
# Requirement already satisfied: sentence_transformers in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from FlagEmbedding) (4.1.0)
# Requirement already satisfied: peft in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from FlagEmbedding) (0.15.2)
# Requirement already satisfied: ir-datasets in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from FlagEmbedding) (0.5.10)
# Requirement already satisfied: sentencepiece in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from FlagEmbedding) (0.2.0)
# Requirement already satisfied: protobuf in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from FlagEmbedding) (6.30.2)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from accelerate>=0.20.1->FlagEmbedding) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from accelerate>=0.20.1->FlagEmbedding) (24.2)
# Requirement already satisfied: psutil in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from accelerate>=0.20.1->FlagEmbedding) (7.0.0)
# Requirement already satisfied: pyyaml in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from accelerate>=0.20.1->FlagEmbedding) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from accelerate>=0.20.1->FlagEmbedding) (0.30.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from accelerate>=0.20.1->FlagEmbedding) (0.5.3)
# Requirement already satisfied: filelock in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from datasets>=2.19.0->FlagEmbedding) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from datasets>=2.19.0->FlagEmbedding) (19.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from datasets>=2.19.0->FlagEmbedding) (0.3.8)
# Requirement already satisfied: pandas in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from datasets>=2.19.0->FlagEmbedding) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from datasets>=2.19.0->FlagEmbedding) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from datasets>=2.19.0->FlagEmbedding) (4.67.1)
# Requirement already satisfied: xxhash in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from datasets>=2.19.0->FlagEmbedding) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from datasets>=2.19.0->FlagEmbedding) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets>=2.19.0->FlagEmbedding) (2024.12.0)
# Requirement already satisfied: aiohttp in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from datasets>=2.19.0->FlagEmbedding) (3.11.16)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.6.0->FlagEmbedding) (4.13.1)
# Requirement already satisfied: networkx in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.6.0->FlagEmbedding) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.6.0->FlagEmbedding) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.6.0->FlagEmbedding) (78.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.6.0->FlagEmbedding) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from sympy==1.13.1->torch>=1.6.0->FlagEmbedding) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from transformers>=4.44.2->FlagEmbedding) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from transformers>=4.44.2->FlagEmbedding) (0.21.1)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from ir-datasets->FlagEmbedding) (4.13.3)
# Requirement already satisfied: inscriptis>=2.2.0 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from ir-datasets->FlagEmbedding) (2.6.0)
# Requirement already satisfied: lxml>=4.5.2 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from ir-datasets->FlagEmbedding) (5.3.2)
# Requirement already satisfied: trec-car-tools>=2.5.4 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from ir-datasets->FlagEmbedding) (2.6)
# Requirement already satisfied: lz4>=3.1.10 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from ir-datasets->FlagEmbedding) (4.4.4)
# Requirement already satisfied: warc3-wet>=0.2.3 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from ir-datasets->FlagEmbedding) (0.2.5)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from ir-datasets->FlagEmbedding) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from ir-datasets->FlagEmbedding) (0.1.9)
# Requirement already satisfied: ijson>=3.1.3 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from ir-datasets->FlagEmbedding) (3.3.0)
# Requirement already satisfied: unlzw3>=0.2.1 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from ir-datasets->FlagEmbedding) (0.2.3)
# Requirement already satisfied: scikit-learn in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from sentence_transformers->FlagEmbedding) (1.6.1)
# Requirement already satisfied: scipy in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from sentence_transformers->FlagEmbedding) (1.13.1)
# Requirement already satisfied: Pillow in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from sentence_transformers->FlagEmbedding) (11.1.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4>=4.4.1->ir-datasets->FlagEmbedding) (2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets>=2.19.0->FlagEmbedding) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets>=2.19.0->FlagEmbedding) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets>=2.19.0->FlagEmbedding) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets>=2.19.0->FlagEmbedding) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets>=2.19.0->FlagEmbedding) (6.3.2)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets>=2.19.0->FlagEmbedding) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets>=2.19.0->FlagEmbedding) (1.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.32.2->datasets>=2.19.0->FlagEmbedding) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.32.2->datasets>=2.19.0->FlagEmbedding) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.32.2->datasets>=2.19.0->FlagEmbedding) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.32.2->datasets>=2.19.0->FlagEmbedding) (2025.1.31)
# Requirement already satisfied: colorama in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.66.3->datasets>=2.19.0->FlagEmbedding) (0.4.6)
# Requirement already satisfied: cbor>=1.0.0 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from trec-car-tools>=2.5.4->ir-datasets->FlagEmbedding) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch>=1.6.0->FlagEmbedding) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from pandas->datasets>=2.19.0->FlagEmbedding) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from pandas->datasets>=2.19.0->FlagEmbedding) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from pandas->datasets>=2.19.0->FlagEmbedding) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->sentence_transformers->FlagEmbedding) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->sentence_transformers->FlagEmbedding) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\administrator\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.19.0->FlagEmbedding) (1.17.0)

# %% [markdown]
# 这段Python代码展示了如何使用**BGE-M3**模型（一种多功能嵌入模型）来计算文本之间的语义相似度。以下是逐步解析：
#
# ---
#
# ### **1. 模型初始化**
# ```python
# model = BGEM3FlagModel('C:\\Users\\Administrator\\AInewModels\\BAAI\\bge-m3', use_fp16=True)
# ```
# - **功能**：加载预训练的BGE-M3模型。
#   - **模型路径**：`C:\Users\Administrator\AInewModels\BAAI\bge-m3`，指向本地下载的模型文件。
#   - **`use_fp16=True`**：启用半精度浮点数（FP16）加速计算，牺牲少量精度换取更快的推理速度。
#
# ---
#
# ### **2. 输入文本准备**
# ```python
# sentences_1 = ["What is BGE M3?", "Defination of BM25"]
# sentences_2 = ["BGE M3 is an embedding model...", "BM25 is a bag-of-words..."]
# ```
# - **两组句子**：
#   - `sentences_1`：包含两个查询问题。
#   - `sentences_2`：包含对应的答案或定义。
#
# ---
#
# ### **3. 生成嵌入向量**
# ```python
# embeddings_1 = model.encode(sentences_1, batch_size=12, max_length=1024)['dense_vecs']
# embeddings_2 = model.encode(sentences_2)['dense_vecs']
# ```
# - **`model.encode()`**：将文本转换为稠密向量（dense embeddings）。
#   - **参数**：
#     - `batch_size=12`：批量处理12个句子，优化GPU利用率。
#     - `max_length=1024`：限制输入文本的最大token长度（默认支持8192，缩短可加速处理）。
#   - **输出**：`dense_vecs`是稠密向量，用于语义相似度计算。
#
# ---
#
# ### **4. 计算相似度**
# ```python
# similarity = embeddings_1 @ embeddings_2.T
# ```
# - **操作**：矩阵乘法（`@`）计算两组嵌入的相似度矩阵。
#   - **结果**：`similarity[i][j]`表示`sentences_1[i]`与`sentences_2[j]`的相似度分数（值越高越相似）。
#   - **示例**：若`sentences_1[0]`（"What is BGE M3?"）与`sentences_2[0]`（"BGE M3 is an embedding model..."）相似度高，则对应分数接近1.0。
#
# ---
#
# ### **关键点总结**
# - **BGE-M3特性**：支持稠密检索、稀疏检索和多向量交互，适用于多语言和长文本场景。
# - **性能优化**：通过`use_fp16`和`max_length`平衡速度与精度。
# - **应用场景**：常用于检索增强生成（RAG）、语义搜索等任务。
#
# 如需进一步了解BGE-M3的架构或训练细节，可参考[官方教程](https://github.com/FlagOpen/FlagEmbedding/tree/master/Tutorials)。

# %%
from FlagEmbedding import BGEM3FlagModel

model = BGEM3FlagModel('C:\\Users\\Administrator\\AInewModels\\BAAI\\bge-m3',  
                       use_fp16=True) # Setting use_fp16 to True speeds up computation with a slight performance degradation

sentences_1 = ["What is BGE M3?", "Defination of BM25"]
sentences_2 = ["BGE M3 is an embedding model supporting dense retrieval, lexical matching and multi-vector interaction.", 
               "BM25 is a bag-of-words retrieval function that ranks a set of documents based on the query terms appearing in each document"]

embeddings_1 = model.encode(sentences_1, 
                            batch_size=12, 
                            #max_length=8192, # If you don't need such a long length, you can set a smaller value to speed up the encoding process.
                            max_length=1024,
                            )['dense_vecs']
embeddings_2 = model.encode(sentences_2)['dense_vecs']
similarity = embeddings_1 @ embeddings_2.T
print(similarity)
# Out:
# You're using a XLMRobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# [[0.6259036  0.34749582]
#  [0.34986773 0.6782464 ]]
